# %% [markdown]
# # Olympic's project visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Abhishek\Downloads\Olympics.csv")
df.head()
# Out:
#                 Name Sex   Age  Height  Weight     Team  Year  Season  \
# 0      Andreea Aanei   F  22.0   170.0   125.0  Romania  2016  Summer
# 1  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  2016  Summer
# 2  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  2016  Summer
# 3  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  2016  Summer
# 4  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  2016  Summer
#
#         Host_City Host_Country          Sport  \
# 0  Rio de Janeiro       Brazil  Weightlifting
# 1  Rio de Janeiro       Brazil     Gymnastics
# 2  Rio de Janeiro       Brazil     Gymnastics
# 3  Rio de Janeiro       Brazil     Gymnastics
# 4  Rio de Janeiro       Brazil     Gymnastics
#
#                                      Event  GDP_Per_Capita_Constant_LCU_Value  \
# 0  Weightlifting Women's Super-Heavyweight                        20450.34567
# 1   Gymnastics Men's Individual All-Around                        23788.15345
# ...

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(8,6))
x=sns.boxplot(x=df['Age'], palette='Set1')
x.set(xlabel='Age', title= 'Boxplot for Age')
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(8,6))
x=sns.boxplot(x=df['Height'], palette='Set1')
x.set(xlabel='Height', title= 'Boxplot for Height')
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(8,6))
x=sns.boxplot(x=df['Weight'], palette='Set1')
x.set(xlabel='Weight', title= 'Boxplot for Weight')
plt.show()

# %%
#Scatter plot between age and weight based on gender

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10,4))
x = sns.scatterplot(x='Age', y='Weight',data=df, palette="Set1", hue='Sex')
x.set(title='Scatterplot for Age and weight based on gender')
plt.show()

# %%
#try for height and weight

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(8,5))
x= sns.scatterplot(x='Height', y='Weight', data=df, palette="Set1", hue='Sex')
x.set(title='Scatterplot for Height and Weight based on gender')
plt.show()

# %%
sns.catplot(data= df, kind='violin',x= 'Age', y= 'Weight',hue= 'Sex', split= True)

# %%
df.corr()
# Out:
#                                         Age    Height    Weight      Year  \
# Age                                1.000000  0.148725  0.216059  0.115478
# Height                             0.148725  1.000000  0.799067  0.063043
# Weight                             0.216059  0.799067  1.000000  0.035977
# Year                               0.115478  0.063043  0.035977  1.000000
# GDP_Per_Capita_Constant_LCU_Value -0.011889 -0.038488 -0.017642  0.042180
# Representing_Host                 -0.007899 -0.003152  0.000215 -0.024700
# Medal                              0.029488  0.079560  0.076688  0.014306
#
#                                    GDP_Per_Capita_Constant_LCU_Value  \
# Age                                                        -0.011889
# Height                                                     -0.038488
# Weight                                                     -0.017642
# Year                                                        0.042180
# ...

# %%
sns.heatmap(df.corr(),annot= True)
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
df_gym = df[df['Sport']=='Gymnastics']
print(df_gym)
# Out:
#                      Name Sex   Age  Height  Weight         Team  Year  \
# 1       Nstor Abad Sanjun   M  23.0   167.0    64.0        Spain  2016
# 2       Nstor Abad Sanjun   M  23.0   167.0    64.0        Spain  2016
# 3       Nstor Abad Sanjun   M  23.0   167.0    64.0        Spain  2016
# 4       Nstor Abad Sanjun   M  23.0   167.0    64.0        Spain  2016
# 5       Nstor Abad Sanjun   M  23.0   167.0    64.0        Spain  2016
# ...                   ...  ..   ...     ...     ...          ...   ...
# 202520       Yu Myeong-Ja   F  17.0   159.0    55.0  Korea, Rep.  1960
# 202521       Yu Myeong-Ja   F  17.0   159.0    55.0  Korea, Rep.  1960
# 202522       Yu Myeong-Ja   F  17.0   159.0    55.0  Korea, Rep.  1960
# 202523       Yu Myeong-Ja   F  17.0   159.0    55.0  Korea, Rep.  1960
# 202524       Yu Myeong-Ja   F  17.0   159.0    55.0  Korea, Rep.  1960
#
#         Season       Host_City Host_Country       Sport  \
# 1       Summer  Rio de Janeiro       Brazil  Gymnastics
# ...

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(8,5))
x=sns.scatterplot(x='Height', y='Weight', data= df_gym, palette= 'Set1',hue='Sex')
x.set(title='Scatter plot for Height and Weight based on Gender for Gymnastics')
plt.show()

# %%
df_wl = df[df['Sport']=='Weightlifting']
print(df_wl)
# Out:
#                                            Name Sex   Age  Height  Weight  \
# 0                                 Andreea Aanei   F  22.0   170.0   125.0
# 14                   Salwan Jasim Abbood Abbood   M  24.0   180.0   104.0
# 27            Ibrahim Ramadan Ibrahim Abdelbaki   M  28.0   173.0    77.0
# 28      Ragab Abdelhay Saad Abdelrazek Abdallah   M  25.0   170.0    94.0
# 96                    Julio Csar Acosta Gonzlez   M  29.0   160.0    62.0
# ...                                         ...  ..   ...     ...     ...
# 202377                           Cornel Wilczek   M  25.0   177.0   117.0
# 202485                         Hiroshi Yamazaki   M  23.0   163.0    69.0
# 202508                            Ivan Yordanov   M  21.0   162.0    67.0
# 202519                                 Yu In-Ho   M  31.0   160.0    56.0
# 202579                          Marian Zieliski   M  30.0   160.0    63.5
#
#                     Team  Year  Season       Host_City Host_Country  \
# ...

# %%
plt.figure(figsize=(8,5))
x=sns.scatterplot(x='Height', y='Weight', data= df_wl, palette= 'Set1',hue='Sex')
x.set(title='Scatter plot for Height and Weight based on Gender for Weightlifting')
plt.show()

# %%
sns.set_style('dark',{'axes.grid': False})
plt.figure(figsize=(8,6))
sns.barplot(x=df['Sex'],y=df['Medal'])
plt.show()

# %%
sns.set_style('dark',{'axes.grid': False})
plt.figure(figsize=(8,4))
g=sns.barplot(x=df['Sex'],y=df['Medal'], estimator= sum, ci= None)
g.set(xticklabels=['Female','Male'],title='Medal Gender wise')
plt.ylabel('Number of Medals')
plt.tight_layout()
plt.show()

# %%
df['Sex'].value_counts()
# Out:
# M    135131
# F     67485
# Name: Sex, dtype: int64

# %%
plt.pie(df['Sex'].value_counts(), labels= ['Male','Female'], autopct= '%1.1f%%')
plt.title('Distribution of Gender')
plt.show()

# %%
df_swim = df[df['Sport']=='Swimming']
print(df_swim)
# Out:
#                              Name Sex   Age  Height     Weight       Team  \
# 51      Matthew Duncan Abeysinghe   M  20.0   180.0  74.000000  Sri Lanka
# 63           Matthew "Matt" Abood   M  30.0   197.0  92.000000  Australia
# 64           Matthew "Matt" Abood   M  30.0   197.0  92.000000  Australia
# 78                   Bourhan Abro   M  21.0   180.0  70.000000   Djibouti
# 85          Javier Carlos Acevedo   M  18.0   182.0  68.000000     Canada
# ...                           ...  ..   ...     ...        ...        ...
# 202531        Farid Zablith Filho   M  18.0   187.0  79.140474     Brazil
# 202539     Nikolaos Zakharopoulos   M  16.0   192.0  76.603291     Greece
# 202565              Elena Zennaro   F  17.0   167.0  57.000000      Italy
# 202566              Elena Zennaro   F  17.0   167.0  57.000000      Italy
# 202584               Hans Zierold   M  22.0   191.0  93.000000    Germany
#
#         Year  Season       Host_City Host_Country     Sport  \
# ...

# %%
df_swim['Team'].value_counts()
# Out:
# United States             1254
# Germany                   1239
# Australia                 1099
# United Kingdom             951
# Canada                     846
#                           ...
# British Virgin Islands       1
# Brunei Darussalam            1
# Lesotho                      1
# Gambia, The                  1
# Congo, Dem. Rep.             1
# Name: Team, Length: 183, dtype: int64

# %%
df_swim_top3 = df_swim.loc[df_swim['Team'].isin(['United States','Germany','Australia'])]

# %%
print(df_swim_top3)
# Out:
#                                     Name Sex   Age  Height  Weight  \
# 63                  Matthew "Matt" Abood   M  30.0   197.0    92.0
# 64                  Matthew "Matt" Abood   M  30.0   197.0    92.0
# 110     Natalie Cammile Adams (-Brannan)   F  24.0   173.0    65.0
# 132               Nathan Ghar-Jun Adrian   M  27.0   198.0   100.0
# 133               Nathan Ghar-Jun Adrian   M  27.0   198.0   100.0
# ...                                  ...  ..   ...     ...     ...
# 202458             Carolyn Virginia Wood   F  14.0   167.0    60.0
# 202459             Carolyn Virginia Wood   F  14.0   167.0    60.0
# 202460             Carolyn Virginia Wood   F  14.0   167.0    60.0
# 202461             Carolyn Virginia Wood   F  14.0   167.0    60.0
# 202584                      Hans Zierold   M  22.0   191.0    93.0
#
#                  Team  Year  Season       Host_City Host_Country     Sport  \
# 63          Australia  2016  Summer  Rio de Janeiro       Brazil  Swimming
# ...

# %%
sns.set_style('whitegrid',{'axes.grid': False})
plt.figure(figsize=(10,4))
sns.barplot(x=df_swim_top3['Sex'], y= df_swim_top3['Height'],ci=None)
plt.xlabel('Gender')
plt.title('Avg Height')
plt.tight_layout()
plt.show()

# %%
sns.set_style('whitegrid',{'axes.grid': False})
plt.figure(figsize=(10,4))
sns.barplot(x=df_swim_top3['Sex'], y= df_swim_top3['Weight'],ci=None)
plt.xlabel('Gender')
plt.title('Avg Weight')
plt.tight_layout()
plt.show()

# %%
sns.set_style('whitegrid',{'axes.grid': False})
plt.figure(figsize=(10,4))
g=sns.barplot(x=df_swim_top3['Sex'], y= df_swim_top3['Medal'], estimator= sum,ci=None)
plt.xlabel("Gender")
plt.ylabel("No. of medals")
plt.title('Gender wise medal')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.histplot(df['Height'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['Height'],bins=10,kde=True,color= 'blue')
plt.title('Histogram for Height with kde')
plt.ylabel('Frequency')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Weight',data= df)
plt.show()

# %%
#for df_swim_top3

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Height',data= df_swim_top3)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
sns.boxplot(x="Team", y="Height", data=df_swim_top3, ax=axes[0])
axes[0].set_xlabel("Team")
axes[0].set_ylabel("Height")
axes[0].set_title("Boxplot")

sns.histplot(data=df_swim_top3, x="Height", bins=20, kde=True, ax=axes[1])
axes[1].set_xlabel("Height")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Histogram")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Time series analyst

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x=df['Year'], y=df['Medal'], ci= None, estimator = sum)
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x=df['Year'],y=df['Height'], ci= None)
plt.ylabel('Average Height')
plt.xlabel('Olymics Year')
plt.title('Lineplot Example')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x=df['Year'],y=df['Height'], hue= df['Sex'], ci= None)
plt.xlabel('Olympics Year')
plt.ylabel('Average Height')
plt.title('Lineplot Example')
plt.show()

# %% [markdown]
# ## Sentiment Analysis

# %%
condition = [(df['Medal']>0),(df['Medal']==0)]
choices= ['Postive','Negative']

# %%
df['Sentiment']=np.select(condition, choices, default= 'Negative')
df
# Out:
#                                          Name Sex   Age  Height  Weight  \
# 0                               Andreea Aanei   F  22.0   170.0   125.0
# 1                           Nstor Abad Sanjun   M  23.0   167.0    64.0
# 2                           Nstor Abad Sanjun   M  23.0   167.0    64.0
# 3                           Nstor Abad Sanjun   M  23.0   167.0    64.0
# 4                           Nstor Abad Sanjun   M  23.0   167.0    64.0
# ...                                       ...  ..   ...     ...     ...
# 202611                          Edward uawnik   M  27.0   165.0    73.0
# 202612                 Nicolaus "Nic" Zwetnow   M  31.0   181.0    70.0
# 202613                   Edward "Eddie" Zwier   M  26.0   176.0    75.0
# 202614  Petronella Veronica Maria "Nel" Zwier   F  23.0   174.0    70.0
# 202615    Galina Ivanovna Zybina (-Fyodorova)   F  29.0   168.0    80.0
#
#                       Team  Year  Season       Host_City Host_Country  \
# ...

# %%
df['Sentiment'].value_counts(normalize= True)
df['Sentiment'].value_counts()
# Out:
# Negative    175313
# Positive     17984
# Neutral       9319
# Name: Sentiment, dtype: int64

# %%
#Sentiment column added already now to check it
df['Sentiment'].unique()
# Out:
# array(['Negative', 'Postive'], dtype=object)

# %%
plt.figure(figsize=(8,6))
plt.pie(df['Sentiment'].value_counts(), labels=df['Sentiment'].value_counts().index,autopct= '%1.1f%%')
plt.show()

# %%
sns.set_style('dark',{'axes.grid': False})
plt.figure(figsize=(8,6))
sns.barplot(x=df['Sentiment'],y=df['Medal'],estimator= sum, ci= None)
plt.tight_layout()
plt.show()

# %%
df['Sentiment'].value_counts().plot(kind= 'bar')
# Out:
# <AxesSubplot:>

# %%
#solving

# %%
conditions = [

    (df['Medal'] >1),

    (df['Medal'] == 0),

    (df['Medal']==1)]

choices = ['Positive', 'Negative','Neutral'] 

df['Sentiment'] = np.select(conditions,choices, default='Negative')

df['Sentiment'].value_counts(normalize=True)
# Out:
# Negative    0.865248
# Positive    0.088759
# Neutral     0.045993
# Name: Sentiment, dtype: float64

# %%
plt.pie(df['Sentiment'].value_counts(),labels=df['Sentiment'].value_counts().index, autopct= '%1.f%%')
plt.show()

# %%
#chart customization

# %%
plt.figure(figsize=(8,4))
plt.scatter(df['Weight'],df['Height'])
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.title('Weight Vs Height')
plt.scatter(df['Weight'],df['Height'], marker= 'o', color= 'yellow', edgecolor='red', s= 50)
plt.xlabel('Weight')
plt.ylabel('Height')
plt.grid()
plt.show()

# %%
#sentiment piechart

# %%
condition = [(df['Medal']>0),(df['Medal']==0)]
choices= ['Postive','Negative']
df['Sentiment']=np.select(condition, choices, default= 'Negative')
df['Sentiment']
# Out:
# 0         Negative
# 1         Negative
# 2         Negative
# 3         Negative
# 4         Negative
#             ...
# 202611    Negative
# 202612    Negative
# 202613    Negative
# 202614    Negative
# 202615    Negative
# Name: Sentiment, Length: 202616, dtype: object

# %%
df['Sentiment'].value_counts()
# Out:
# Negative    175313
# Postive      27303
# Name: Sentiment, dtype: int64

# %%
plt.figure(figsize=(8,4))
plt.pie(df['Sentiment'].value_counts())
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.pie(df['Sentiment'].value_counts(), labels=df['Sentiment'].value_counts().index, autopct= '%1.1f%%', startangle=90, explode= [0,0.2],colors= ['r','g'])
plt.show()

# %%
#practicing sheet

# %%
conditions = [

    (df['Medal'] >1),

    (df['Medal'] == 0),

    (df['Medal']==1)]

choices = ['Positive', 'Negative','Neutral'] 

df['Sentiment'] = np.select(conditions,choices, default='Negative')

# %%
plt.figure(figsize=(9,6))
plt.pie(df['Sentiment'].value_counts(),labels=df['Sentiment'].value_counts().index, autopct= '%1.1f%%', startangle=90, colors=['r','g','b'],shadow=True)
plt.legend(title='Sentiment')
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.pie(df['Sentiment'].value_counts(),labels=df['Sentiment'].value_counts().index, autopct= '%1.1f%%', startangle=90, colors=['r','g','b'],shadow=True,  explode =[0,0.3,0])
plt.legend(title='Sentiment')
plt.show()

# %% [markdown]
# ## Advanced Charts in Seaborn and Chart customization

# %%
df_swim_top3 = df_swim.loc[df_swim['Team'].isin(['United States','Germany','Australia'])]
print(df_swim_top3)
# Out:
#                                     Name Sex   Age  Height  Weight  \
# 63                  Matthew "Matt" Abood   M  30.0   197.0    92.0
# 64                  Matthew "Matt" Abood   M  30.0   197.0    92.0
# 110     Natalie Cammile Adams (-Brannan)   F  24.0   173.0    65.0
# 132               Nathan Ghar-Jun Adrian   M  27.0   198.0   100.0
# 133               Nathan Ghar-Jun Adrian   M  27.0   198.0   100.0
# ...                                  ...  ..   ...     ...     ...
# 202458             Carolyn Virginia Wood   F  14.0   167.0    60.0
# 202459             Carolyn Virginia Wood   F  14.0   167.0    60.0
# 202460             Carolyn Virginia Wood   F  14.0   167.0    60.0
# 202461             Carolyn Virginia Wood   F  14.0   167.0    60.0
# 202584                      Hans Zierold   M  22.0   191.0    93.0
#
#                  Team  Year  Season       Host_City Host_Country     Sport  \
# 63          Australia  2016  Summer  Rio de Janeiro       Brazil  Swimming
# ...

# %%
sns.set_style('white')
plt.figure(figsize=(8,6))
sns.violinplot(x=df_swim_top3['Sex'],y=df_swim_top3['Height'])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.violinplot(x=df_swim_top3['Sex'],y=df_swim_top3['Height'],hue= df_swim_top3['Team'])
plt.show()

# %%
#customizing it

# %%
sns.set_style('darkgrid',{'axes.grid': False})
plt.figure(figsize=(8,6))
sns.violinplot(x=df_swim_top3['Sex'],y=df_swim_top3['Height'],hue=df_swim_top3['Team'])
plt.xlabel('Gender')
plt.show()

# %%
sns.set_style('darkgrid',{'axes.grid': True})
plt.figure(figsize=(8,6))
sns.violinplot(x=df_swim_top3['Sex'],y=df_swim_top3['Height'],hue=df_swim_top3['Team'],color='yellow', saturation= 0.6)
plt.xlabel('Gender')
plt.show()

# %%
# Solving 
df_judo = df[df['Sport']=='Judo']
df_judo['Team'].value_counts()
# Out:
# Germany       135
# France        135
# Japan         129
# China         125
# Brazil        120
#              ...
# Jordan          1
# Sri Lanka       1
# Cambodia        1
# Cabo Verde      1
# Malaysia        1
# Name: Team, Length: 166, dtype: int64

# %%
df_judo = df[df['Sport']=='Judo']
df_judo['Team'].value_counts()
df_judo_top3 = df_judo.loc[df_judo['Team'].isin(['Germany','France','Japan'])]
df_judo_top3.head()
# Out:
#                      Name Sex   Age  Height  Weight     Team  Year  Season  \
# 151   Clarisse Agbegnenou   F  23.0   164.0    66.0   France  2016  Summer
# 450           milie Andol   F  28.0   170.0    97.0   France  2016  Summer
# 780           Mashu Baker   M  21.0   178.0    90.0    Japan  2016  Summer
# 1530     Andre Breitbarth   M  26.0   191.0   125.0  Germany  2016  Summer
# 3175        Pierre Duprat   M  26.0   175.0    73.0   France  2016  Summer
#
#            Host_City Host_Country Sport                           Event  \
# 151   Rio de Janeiro       Brazil  Judo  Judo Women's Half-Middleweight
# 450   Rio de Janeiro       Brazil  Judo        Judo Women's Heavyweight
# 780   Rio de Janeiro       Brazil  Judo         Judo Men's Middleweight
# 1530  Rio de Janeiro       Brazil  Judo          Judo Men's Heavyweight
# 3175  Rio de Janeiro       Brazil  Judo          Judo Men's Lightweight
#
#       GDP_Per_Capita_Constant_LCU_Value  Representing_Host Avg_Temp  Medal  \
# ...

# %%
df_tae = df[df['Sport']=='Taekwondo']
df_tae['Team'].value_counts().head(3)
# Out:
# China          34
# Australia      22
# Korea, Rep.    21
# Name: Team, dtype: int64

# %%
df_tae = df[df['Sport']=='Taekwondo']
df_tae['Team'].value_counts()
df_tae_top3 = df_tae.loc[df_tae['Team'].isin(['China','Australia','Korea, Rep.'])]
df_tae_top3.head()
# Out:
#                   Name Sex   Age  Height  Weight         Team  Year  Season  \
# 2241  Chuang Chia-Chia   F  27.0   179.0    65.0        China  2016  Summer
# 5069  Huang Huai-Hsuan   F  19.0   168.0    53.0        China  2016  Summer
# 5314       Ja Dong-Min   M  29.0   190.0    91.0  Korea, Rep.  2016  Summer
# 5835     Safwan Khalil   M  30.0   184.0    58.0    Australia  2016  Summer
# 5972        Kim So-Hui   F  22.0   164.0    50.0  Korea, Rep.  2016  Summer
#
#            Host_City Host_Country      Sport                           Event  \
# 2241  Rio de Janeiro       Brazil  Taekwondo  Taekwondo Women's Welterweight
# 5069  Rio de Janeiro       Brazil  Taekwondo     Taekwondo Women's Flyweight
# 5314  Rio de Janeiro       Brazil  Taekwondo     Taekwondo Men's Heavyweight
# 5835  Rio de Janeiro       Brazil  Taekwondo       Taekwondo Men's Flyweight
# 5972  Rio de Janeiro       Brazil  Taekwondo     Taekwondo Women's Flyweight
#
# ...

# %%
sns.set_style("whitegrid", {'axes.grid' : False})  
plt.figure(figsize=(10, 6))
sns.violinplot(x="Sex", y="Height", data=df_judo_top3, hue='Team', dodge=True,saturation =0.5, color='Yellow')
plt.title("Violin Plot ")
plt.xlabel("Gender")
plt.ylabel("Height")
plt.show()

# %%
sns.set_style("whitegrid", {'axes.grid' : False})  
plt.figure(figsize=(10, 6))
sns.violinplot(x="Sex", y="Height", data=df_tae_top3, hue='Team', dodge=True,saturation =0.5, color='Yellow')
plt.title("Violin Plot ")
plt.xlabel("Gender")
plt.ylabel("Height")
plt.show()

# %%
sns.kdeplot(data=df_tae_top3,x='Height', y='Weight', hue='Sex', fill=False)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
sns.kdeplot(data=df_tae_top3,x='Height', y='Weight', hue='Sex', fill=True)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
sns.kdeplot(data=df_tae_top3,x='Height', y='Weight', hue='Sex', levels=5, thresh=0)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>
